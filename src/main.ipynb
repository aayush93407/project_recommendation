# %%
from pptx import Presentation
from mistralai import Mistral
from fpdf import FPDF
from pdfminer.high_level import extract_text
import mistune
from mistune.renderers.markdown import MarkdownRenderer
import pypandoc
import os
from dotenv import load_dotenv
import csv
import re

# %%
def extract_text_pdf(pdf_path):
    text = extract_text(pdf_path)
    return text

# %%
pdf_path = '../data/pdf/college_resume.pdf'
# Out:
# AAYUSH KUMAR
# Address: Rishi comforts PG 578,
# 60 Feet Rd, AECS, Layout - C Block,
# Marathahalli, Bengaluru Karnataka - 560037
# Email ID: aaku21ainds@cmrit.ac.in
# Mobile No: +91 895 593 1443
# LinkedIn : https://www.linkedin.com/in/aayush-kumar-6b5191263/
# GitHub: Aayush-93407
#  CAREER OBJECTIVE
# Dynamic  and  driven  Bachelor  of  Engineering  graduate  from  CMR  Institute  of  Technology,  specializing  in  Artificial
# Intelligence and Data Science, seeking a challenging role where I can leverage my strong analytical skills and passion
# for  innovation.  Committed  to  continuous  learning  and  professional  growth,  drive  efficiency,  and  create  value  in  a
# dynamic and collaborative environment.
#  EDUCATION QUALIFICATION
# •  Bachelors of Engineering – Artificial Intelligence and Data Science Engineering
#
# CMR Institute of Technology, Bengaluru
# 9.03 CGPA, 2025(Pursuing)
#
# •  12th Grade – Science
#
# Central Academy, Kota, Rajasthan
# 79.6%, 2021
# •  10th Grade
#
# Excellent Public School, Lokapur
# 91%, 2019
#  TECHNICAL SKILLS
# Languages: Python, C++, Java (Intermediate), C (Intermediate), Arduino IDE (basic)
# Software: ROS, Eclipse, Solid-Edge, VS Code, PyCharm, Arduino IDE.
# Skills: Frontend: React Native, React.js, HTML5, CSS3, JavaScript, Bootstrap| Backend: Node.js, Express.js, REST APIs |
# Databases: MySQL | Version Control: Git, GitHub| Other: Axios, React Router, Postman, NPM
#  PROJECTS
# •  Title: Geo Guide bot
#
# Description: Innovated a cutting-edge surveillance system with OpenCV and machine learning; deployed drone
# technology for event classification and live bot tracking, achieving a 35% improvement in operational efficiency
# and coverage.
# Tools used: Arduino IDE, QGIS, VS code
# Learning Outcome: Learnt IR sensors, Arduino IDE language, QGIS software, hardware components.
#
# •  Title: Blockchain based e-Vault:
#
# Description: Engineered a blockchain-based e-Vault for secure document storage leveraging IPFS and Ethereum
# smart contracts; prioritized gas fee reduction and authorization management, enhancing efficiency by 40% and
# security by 30%.
# Tools used: IPFS, Ethereum, Smart-contract.
# Learning Outcome: Learned the use of integration of IPFS and Ethereum.
#
# •  Title: Blogging Website:
#
# Description: Engineered a feature-rich blogging platform with JavaScript; facilitated user interaction by integrating
# add/delete blog functionality and video uploads, leading to a 40% rise in user- generated content.
# Tools used: Tech stack Java Script, Node JS
# Learning Outcome: Developed an understanding of building a blogging website using Java Script.
#
#   INTERNSHIPS
# •  AuxPlutes Tech
#
# Duration: Oct, 2024 – Jan, 2025
# Designation: AI Engineer Intern
# Roles & Responsibilities:
# o  Developing responsive user interfaces using React.js. Also using React Native for app development.
# o
# o  Utilizing React Router for efficient navigation and dynamic routing.
#
# Integrating AI/ML models to improve system intelligence and decision-making.
#
#
#
#
#
#
# •  EBTS Organization
#
# Duration: July, 2024 – Aug, 2024
# Designation: Machine Learning Intern
# Roles & Responsibilities:
# o  Developed projects based on supervised learning, SVM
# CO-CURRICULAR ACTIVITIES & EXTRA CURRICULAR ACTIVITIES
# Co-Curricular Activities
# •  Seminars: Attended a webinar on topic “Configuration of Cyber Security” organized by CMRIT.
# •  Online Courses:
#
# o  Blender from Udemy
# o  Cyber Security from Skill Learn
#
# •  Certifications:
#
# o  C (Coursera)
# o  Web Development (Udemy)
# o  Python for Data Science (Udemy)
# •
# Industrial Visits: Visited HAL in the year 2023
# •  Hackathons: Participated in following Hackathons:
#
# o  SBI Hack-AI-Thon in 2025
# o  SIH in 2024
# o  MANTHAN organized by FKCCI
# o  EYSS in 2022
# o  SIH in 2023
# o  eYRC in 2023.
# Extra – Curricular Activities:
# •  Sports: Participated in Chess and Table Tennis in Spardha Sports Fest 2022.
#  AWARDS & ACHIEVEMENTS
# •  Qualified for final stage in SIH 2024.
# •  Won 1st place in inter college Technovation-2024 contest conducted by AIDS department.
# •  Won 2nd place in inter college TEXPLORE-2024 contest conducted by IEEE.
# •  Reached Semifinals in EYSS in 2022.
# •  Qualified for the second stage in eYRC in 2023 conducted by IIT, Bombay.
#  PERSONAL DETAILS
# Date of Birth
# Gender
# Nationality
# Permanent Address
# Languages Known
# Hobbies
#  REFERENCE
# Name: Dr. Shanthi M B
# Designation: HOD, Dept of AINDS, CMRIT
# Email ID: hod.aids@cmrit.ac.in
# Phone No: +91 9741414002
#
# : 22/05/2003
# : Male
# : Indian
# : Plot no.62, Bari Co-operative Colony, Bokaro Steel City, Jharkhand - 827010
# : English, Hindi, Kannada
# : Playing Chess, Badminton
#
# Name: Dr. Nageswara Rao
# Designation: Asst. Professor, Dept of EE, CMRIT
# Email ID: Nageswara.r@cmrit.ac.in
# Phone No: +91 9652114714

# %%
def extract_text_ppt(ppt_path):
    ppt = Presentation(ppt_path)
    text = ""
    for slide in ppt.slides:
        for shape in slide.shapes:
            if hasattr(shape, "text"):
                text += shape.text + "\n\n"
    
    return text

# %%
def generate_notes_mistral(text, api_key_mistral):
    model = "mistral-large-latest"
    prompt = f"Analyze this text from a resume and return the following information on new lines \nName, Email ID, Contact Number, LinkedIn and GitHub page links, and extract all skills from projects and those under the skills section and pack them all under the skills field, seperated by commas \nGive me these details in the form field_name : values, each on a new line\nPlease make sure the field names are exactly like this: Name, Email ID, Contact Number, LinkedIn, GitHub, Skills\n{text}"
    
    client = Mistral(api_key=api_key_mistral)
    
    completion = client.chat.complete(
        model=model,
        messages=[
            {
                "role":"user",
                "content": prompt
            }
        ]
    )
    return completion.choices[0].message.content

# %%
def recommend_projects(skills, api_key_mistral):
    model = "mistral-large-latest"
    prompt = f"Based on the skills provided below, recommend top 5 projects that the user can work on and successfully complete\nGenerate your response in this format: Project Name, Project Description, Tools and Skills Utilized, and Steps \n{skills}"
    
    client = Mistral(api_key=api_key_mistral)
    completion = client.chat.complete(
        model=model,
        messages = [
            {
                "role":"user", 
                "content":prompt
            }
        ]
    )
    
    return completion.choices[0].message.content

# %% [markdown]
# **MAIN FOR RESUME FIELD EXTRACTION**

# %%
def main():
    filepath = '../data/pdf/1CR21EC252_ADARSHVINOD_RESUME.pdf'
    api_key_mistral = "aKFEMuDwJOvtphHDDOrh2qbfRP7jEA1L"
    
    if os.path.splitext(filepath)[1] == '.pdf':
        resume_text = extract_text_pdf(filepath)
        
    user_info = generate_notes_mistral(resume_text, api_key_mistral)
    
    user_info_dict = {}
    lines = user_info.split("\n")
    for line in lines:
        key, *value = line.split(':', 1)
        if not value:
            continue
        user_info_dict[key.strip()] = value[0].strip()
        
    print(user_info_dict)
        
   
    
    csv_filename = "user_info.csv"
    with open(csv_filename, mode="a", newline="") as file:
        fieldnames = ["Name", "Email ID", "Contact Number", "LinkedIn", "GitHub", "Skills"]
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        
        if file.tell() == 0:
            writer.writeheader()
            
        writer.writerow(user_info_dict)
        
        file.close()
        
    projects = recommend_projects(user_info_dict["Skills"], api_key_mistral)
    # projects -> string
    print(projects)

# %%
main()
# Out:
# {'Name': 'ADARSH VINOD', 'Email ID': 'advi21ee@cmrit.ac.in', 'Contact Number': '+91 9284597756', 'LinkedIn': 'www.linkedin.com/in/adarshvinod692021', 'GitHub': 'https://github.com/devAdarsh19', 'Skills': 'C, Python, Java, Matlab, Scilab, Cadence Virtuoso, Intel Quartus Prime, VS Code, Unity, Git, SQLite3, MySQL, HTML, CSS, JavaScript, React, Django, Bootstrap, OpenCV, Machine Learning, QGIS, Arduino, ESP32, ReactJS, Bootstrap, NewsAPI, Django (Python), HTML, CSS, VS Code, Circumeo, MailTrap, Stripe, Django, web application data management'}
# ### Project 1: Smart Home Automation System
# **Project Description:** Design and implement a smart home automation system using IoT devices and cloud-based control.
# **Tools and Skills Utilized:** Arduino, ESP32, Python, Unity, Git, HTML, CSS, JavaScript, React, Django, SQLite3, Bootstrap, Intel Quartus Prime, VS Code
# **Steps:**
# 1. **Hardware Setup:** Configure Arduino and ESP32 modules for sensor data collection.
# 2. **Firmware Development:** Write firmware in C for Arduino and ESP32 to manage sensor data.
# 3. **Backend Development:** Develop a Django-based backend to handle data from IoT devices.
# 4. **Database Setup:** Use SQLite3 to store sensor data and user preferences.
# 5. **Frontend Development:** Create a responsive web interface using HTML, CSS, JavaScript, React, and Bootstrap.
# 6. **Cloud Integration:** Integrate the system with cloud services for remote control and data analysis.
# 7. **Testing and Deployment:** Test the system thoroughly and deploy it using Git for version control.
#
# ### Project 2: Real-Time Weather Monitoring System
# **Project Description:** Build a real-time weather monitoring system that collects data from sensors and displays it on a web interface.
# **Tools and Skills Utilized:** Arduino, ESP32, Python, Django, HTML, CSS, JavaScript, React, Bootstrap, OpenCV, SQLite3, Git, VS Code
# **Steps:**
# 1. **Hardware Setup:** Set up Arduino and ESP32 modules with weather sensors.
# 2. **Data Collection:** Write firmware in C to collect weather data from sensors.
# 3. **Backend Development:** Develop a Django-based backend to process and store weather data.
# 4. **Database Setup:** Use SQLite3 to store the collected weather data.
# 5. **Frontend Development:** Create a web interface using HTML, CSS, JavaScript, React, and Bootstrap to display real-time weather data.
# 6. **Data Visualization:** Use OpenCV for any image processing needs related to weather data.
# 7. **Testing and Deployment:** Test the system and deploy it using Git for version control.
#
# ### Project 3: E-commerce Web Application
# **Project Description:** Develop a fully functional e-commerce web application with user authentication, product management, and payment integration.
# **Tools and Skills Utilized:** Django, Python, HTML, CSS, JavaScript, React, Bootstrap, MySQL, Stripe, Git, VS Code
# **Steps:**
# 1. **Backend Development:** Develop a Django-based backend to handle product management, user authentication, and order processing.
# 2. **Database Setup:** Use MySQL to store product information, user data, and order details.
# 3. **Frontend Development:** Create a responsive web interface using HTML, CSS, JavaScript, React, and Bootstrap.
# 4. **Payment Integration:** Integrate Stripe for secure payment processing.
# 5. **Testing and Deployment:** Test the application thoroughly and deploy it using Git for version control.
#
# ### Project 4: News Aggregator Web Application
# **Project Description:** Create a web application that aggregates news from various sources and displays them in a user-friendly interface.
# **Tools and Skills Utilized:** Django, Python, HTML, CSS, JavaScript, React, Bootstrap, NewsAPI, Git, VS Code
# **Steps:**
# 1. **Backend Development:** Develop a Django-based backend to fetch news data from NewsAPI.
# 2. **Frontend Development:** Create a web interface using HTML, CSS, JavaScript, React, and Bootstrap to display the news articles.
# 3. **Data Fetching:** Use NewsAPI to fetch news data from various sources.
# 4. **Testing and Deployment:** Test the application and deploy it using Git for version control.
#
# ### Project 5: Interactive Mapping Application
# **Project Description:** Develop an interactive mapping application that allows users to visualize geospatial data and perform analysis.
# **Tools and Skills Utilized:** Python, Django, HTML, CSS, JavaScript, React, Bootstrap, QGIS, Git, VS Code, SQLite3
# **Steps:**
# 1. **Backend Development:** Develop a Django-based backend to manage geospatial data.
# 2. **Database Setup:** Use SQLite3 to store geospatial data.
# 3. **Frontend Development:** Create a web interface using HTML, CSS, JavaScript, React, and Bootstrap to visualize maps and data.
# 4. **Geospatial Data Handling:** Use QGIS to handle and analyze geospatial data.
# 5. **Testing and Deployment:** Test the application and deploy it using Git for version control.
